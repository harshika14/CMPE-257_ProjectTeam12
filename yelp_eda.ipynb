# %% [markdown]
# #  Data preprocessing on Yelp data set

# %%
import matplotlib.pyplot as plt # plotting
import numpy as np # linear algebra
import os # accessing directory structure
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import plotly.express as px
from pandasql import sqldf

# %% [markdown]
# ## Reading the data from business dataset

# %%
#reading json file-yelp_academic_dataset_business.json
yelp_academic_dataset_business_json_path = '/Users/swapnakotha/Desktop/CMPE-257/yelp_dataset/yelp_academic_dataset_business.json'
yelp_business_dataset_json = pd.read_json(yelp_academic_dataset_business_json_path, lines=True)
#printing the overview of the business dataset
print(yelp_business_dataset_json.shape)
print('No of records in business dataset',yelp_business_dataset_json.shape[0])
print('No of features in business dataset',yelp_business_dataset_json.shape[1])
yelp_business_dataset_json.head()
# Out:
# (150346, 14)
# No of records in business dataset 150346
# No of features in business dataset 14
#               business_id                      name  \
# 0  Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 1  mpf3x-BjTdTEA3yCZrAYPw             The UPS Store
# 2  tUFrWirKiKi_TAnsVWINQQ                    Target
# 3  MTSW4McQd7CbVtyjqoe9mw        St Honore Pastries
# 4  mWMc6_wTdE0EUBKIGXDVfA  Perkiomen Valley Brewery
#
#                            address           city state postal_code  \
# 0           1616 Chapala St, Ste 2  Santa Barbara    CA       93101
# 1  87 Grasso Plaza Shopping Center         Affton    MO       63123
# 2             5255 E Broadway Blvd         Tucson    AZ       85711
# 3                      935 Race St   Philadelphia    PA       19107
# 4                    101 Walnut St     Green Lane    PA       18054
#
#     latitude   longitude  stars  review_count  is_open  \
# 0  34.426679 -119.711197    5.0             7        0
# 1  38.551126  -90.335695    3.0            15        1
# 2  32.223236 -110.880452    3.5            22        0
# 3  39.955505  -75.155564    4.0            80        1
# 4  40.338183  -75.471659    4.5            13        1
#
#                                           attributes  \
# 0                      {'ByAppointmentOnly': 'True'}
# 1             {'BusinessAcceptsCreditCards': 'True'}
# 2  {'BikeParking': 'True', 'BusinessAcceptsCredit...
# 3  {'RestaurantsDelivery': 'False', 'OutdoorSeati...
# 4  {'BusinessAcceptsCreditCards': 'True', 'Wheelc...
#
#                                           categories  \
# 0  Doctors, Traditional Chinese Medicine, Naturop...
# 1  Shipping Centers, Local Services, Notaries, Ma...
# 2  Department Stores, Shopping, Fashion, Home & G...
# 3  Restaurants, Food, Bubble Tea, Coffee & Tea, B...
# 4                          Brewpubs, Breweries, Food
#
#                                                hours
# 0                                               None
# 1  {'Monday': '0:0-0:0', 'Tuesday': '8:0-18:30', ...
# 2  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 3  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 4  {'Wednesday': '14:0-22:0', 'Thursday': '16:0-2...

# %%
# 1 = open, 0 = closed
# There are significant amount of businesses that are not open anymore,
yelp_business_dataset_json.is_open.value_counts()
# Out:
# 1    119698
# 0     30648
# Name: is_open, dtype: int64

# %%
df_categories =yelp_business_dataset_json.assign(categories = yelp_business_dataset_json.categories.str.split(', ')).explode('categories')
df_categories.sample(3)
# Out:
#                    business_id                 name  \
# 683     HxlFnUI9-RNKlKD2zUwzWQ  Skippack Sweet Spot
# 129108  BXxoVfl65fOkacs_WS5CRw         Coast Dental
# 61727   QgwCGkTvxvkl3qUR2t6Dqw   Skin Renew Day Spa
#
#                            address          city state postal_code   latitude  \
# 683             4019 Skippack Pike      Skippack    PA       19474  40.223222
# 129108  10427 Ulmerton Rd, Ste B-3         Largo    FL       33771  27.896325
# 61727          5220 E Southport Rd  Indianapolis    IN       46237  39.667321
#
#         longitude  stars  review_count  is_open  \
# 683    -75.399023    3.5            18        1
# 129108 -82.784214    1.5            19        1
# 61727  -86.079612    4.5             7        1
#
#                                                attributes          categories  \
# 683     {'BikeParking': 'True', 'RestaurantsPriceRange...        Candy Stores
# 129108                     {'ByAppointmentOnly': 'False'}       Orthodontists
# 61727              {'BusinessAcceptsCreditCards': 'True'}  Laser Hair Removal
#
#                                                     hours
# 683     {'Monday': '15:0-21:0', 'Wednesday': '9:0-18:0...
# 129108  {'Monday': '8:0-17:0', 'Tuesday': '8:0-17:0', ...
# 61727   {'Monday': '0:0-0:0', 'Tuesday': '10:0-19:0', ...

# %% [markdown]
# ## Getting the categories

# %%
#showing the business categories 
print('Total number of categories:', len(df_categories.categories.value_counts()))
#showing the top 20 business categories
print('Top 20 categories:')
df_categories.categories.value_counts()[:20]
# Out:
# Total number of categories: 1311
# Top 20 categories:
# Restaurants                  52268
# Food                         27781
# Shopping                     24395
# Home Services                14356
# Beauty & Spas                14292
# Nightlife                    12281
# Health & Medical             11890
# Local Services               11198
# Bars                         11065
# Automotive                   10773
# Event Planning & Services     9895
# Sandwiches                    8366
# American (Traditional)        8139
# Active Life                   7687
# Pizza                         7093
# Coffee & Tea                  6703
# Fast Food                     6472
# Breakfast & Brunch            6239
# American (New)                6097
# Hotels & Travel               5857
# Name: categories, dtype: int64

# %%
df_categories
# Out:
#                    business_id                      name  \
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# 0       Pns2l4eNsfO8kk83dixA6A  Abby Rappoport, LAC, CMQ
# ...                        ...                       ...
# 150344  mtGm22y5c2UHNXDFAjaPNw  Cyclery & Fitness Center
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
# 150345  jV_XOycEzSlTx-65W906pg                   Sic Ink
#
#                        address           city state postal_code   latitude  \
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# 0       1616 Chapala St, Ste 2  Santa Barbara    CA       93101  34.426679
# ...                        ...            ...   ...         ...        ...
# 150344            2472 Troy Rd   Edwardsville    IL       62025  38.782351
# 150345   238 Apollo Beach Blvd   Apollo beach    FL       33572  27.771002
# 150345   238 Apollo Beach Blvd   Apollo beach    FL       33572  27.771002
# 150345   238 Apollo Beach Blvd   Apollo beach    FL       33572  27.771002
# 150345   238 Apollo Beach Blvd   Apollo beach    FL       33572  27.771002
#
#          longitude  stars  review_count  is_open  \
# 0      -119.711197    5.0             7        0
# 0      -119.711197    5.0             7        0
# 0      -119.711197    5.0             7        0
# 0      -119.711197    5.0             7        0
# 0      -119.711197    5.0             7        0
# ...            ...    ...           ...      ...
# 150344  -89.950558    4.0            24        1
# 150345  -82.394910    4.5             9        1
# 150345  -82.394910    4.5             9        1
# 150345  -82.394910    4.5             9        1
# 150345  -82.394910    4.5             9        1
#
#                                                attributes  \
# 0                           {'ByAppointmentOnly': 'True'}
# 0                           {'ByAppointmentOnly': 'True'}
# 0                           {'ByAppointmentOnly': 'True'}
# 0                           {'ByAppointmentOnly': 'True'}
# 0                           {'ByAppointmentOnly': 'True'}
# ...                                                   ...
# 150344  {'BusinessParking': '{'garage': False, 'street...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
# 150345  {'WheelchairAccessible': 'True', 'BusinessAcce...
#
#                           categories  \
# 0                            Doctors
# 0       Traditional Chinese Medicine
# 0              Naturopathic/Holistic
# 0                        Acupuncture
# 0                   Health & Medical
# ...                              ...
# 150344                         Bikes
# 150345                 Beauty & Spas
# 150345              Permanent Makeup
# 150345                      Piercing
# 150345                        Tattoo
#
#                                                     hours
# 0                                                    None
# 0                                                    None
# 0                                                    None
# 0                                                    None
# 0                                                    None
# ...                                                   ...
# 150344  {'Monday': '9:0-20:0', 'Tuesday': '9:0-20:0', ...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
# 150345  {'Tuesday': '12:0-19:0', 'Wednesday': '12:0-19...
#
# [668695 rows x 14 columns]

# %%
df_state = yelp_business_dataset_json.assign(categories = yelp_business_dataset_json.state.str.split(', ')).explode('state')
df_state.sample(3)
# Out:
#                   business_id               name                address  \
# 3749   OUSHKQ9AaBNvX90fUFMU_Q  Champ's Dog House             163 Rte 70
# 21664  ysTxtSfkEpqoHXb4bcfjXQ    Action Hardware          1812 Marsh Rd
# 75245  ub_cFc5t2sgFSG-Ug2K7Qw  ALMA Rest And Bar  2223 N Westshore Blvd
#
#              city state postal_code   latitude  longitude  stars  \
# 3749      Medford    NJ       08055  39.901745 -74.839359    4.5
# 21664  Wilmington    DE       19810  39.803865 -75.504063    4.0
# 75245       Tampa    FL       33607  27.965889 -82.520836    3.5
#
#        review_count  is_open  \
# 3749             33        1
# 21664            11        1
# 75245            63        1
#
#                                               attributes categories  \
# 3749                                                None       [NJ]
# 21664  {'BusinessAcceptsCreditCards': 'True', 'Busine...       [DE]
# 75245  {'RestaurantsDelivery': 'True', 'CoatCheck': '...       [FL]
#
#                                                    hours
# 3749   {'Monday': '6:30-18:0', 'Tuesday': '6:30-18:0'...
# 21664  {'Monday': '8:0-16:0', 'Tuesday': '8:0-20:0', ...
# 75245  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...

# %%
#printing the number of states in which the businesses are available 
print('Total number of categories:', len(df_state.state.value_counts()))
# Out:
# Total number of categories: 27

# %% [markdown]
# ## Cleaning the dataset

# %%
#countof missing values for each attribute
df_categories.isna().sum()
# Out:
# business_id         0
# name                0
# address             0
# city                0
# state               0
# postal_code         0
# latitude            0
# longitude           0
# stars               0
# review_count        0
# is_open             0
# attributes      46607
# categories        103
# hours           73794
# dtype: int64

# %%
#Eliminating the missing values
df_categories_clean=df_categories.dropna()

# %%
df_categories_clean.isna().sum()
# Out:
# business_id     0
# name            0
# address         0
# city            0
# state           0
# postal_code     0
# latitude        0
# longitude       0
# stars           0
# review_count    0
# is_open         0
# attributes      0
# categories      0
# hours           0
# dtype: int64

# %% [markdown]
# ### Selecting a few categories from the larger dataset and merging them with reviews json

# %%
#Taking the business which are classified as 'Active Life' and creating a smaller subset
active_life = df_categories_clean[df_categories_clean['categories'].str.contains("Active Life")]
active_life
# Out:
#                    business_id                                     name  \
# 30      fvWn8oXXwbj2l79cochZyw         Altitude Trampoline Park - Boise
# 38      LcAozWCMLGjwRbokaJAKMg           Edwardsville Children's Museum
# 50      Hwt3_mOEmU-t--ywcemnMg                               Gold's Gym
# 100     8KMIT0NXu30Jz5Ojo5uxaw  Cornerstone Physical Therapy Associates
# 109     I6DCYks9lqZeoZiVzW7PmA                            Its Sold Here
# ...                        ...                                      ...
# 150278  jYd7okFv6JMjIXMDjZNCDQ                                 Ace Golf
# 150285  fWeWzB9STxcX40AgSEQVcw             Arizona-Sonora Desert Museum
# 150303  JhSByBTYY1rGstRy76YmLA                        Reiki with Darren
# 150334  LJ4GjQ1HL6kqvIPpNUNNaQ                 Shanti Yoga and Ayurveda
# 150338  fn3ybdsRSrIDpKZTsRuAWg         INSPcenter/Thai Clinical Massage
#
#                             address            city state postal_code  \
# 30              1301 N Milwaukee St           Boise    ID       83704
# 38                  722 Holyoake Rd    Edwardsville    IL       62025
# 50                 203 - 38th Ave N  St. Petersburg    FL       33704
# 100      1338 Bristol Pike, Ste 203        Bensalem    PA       19020
# 109                      94 York Rd    Willow Grove    PA       19090
# ...                             ...             ...   ...         ...
# 150278              820 S Kings Ave         Brandon    FL       33511
# 150285             2021 N Kinney Rd          Tucson    AZ       85743
# 150303                                Santa Barbara    CA       93105
# 150334           1638 Pine St, Fl 1    Philadelphia    PA       19103
# 150338  2625 N Meridian St, Unit 50    Indianapolis    IN       46208
#
#          latitude   longitude  stars  review_count  is_open  \
# 30      43.616763 -116.285382    5.0            30        1
# 38      38.804395  -89.949733    4.5            12        1
# 50      27.808339  -82.636168    3.0            17        0
# 100     40.072204  -74.964420    5.0             6        1
# 109     40.142849  -75.114379    1.5            10        1
# ...           ...         ...    ...           ...      ...
# 150278  27.926009  -82.295597    3.0            30        0
# 150285  32.243733 -111.166815    4.5           448        1
# 150303  34.420831 -119.698190    5.0             7        1
# 150334  39.945966  -75.169666    4.5            39        1
# 150338  39.805057  -86.155975    4.0            12        1
#
#                                                attributes   categories  \
# 30      {'BusinessParking': '{'garage': False, 'street...  Active Life
# 38      {'GoodForKids': 'True', 'BusinessAcceptsCredit...  Active Life
# 50      {'GoodForKids': 'True', 'BusinessAcceptsCredit...  Active Life
# 100     {'BusinessAcceptsCreditCards': 'True', 'ByAppo...  Active Life
# 109     {'BusinessAcceptsCreditCards': 'False', 'Resta...  Active Life
# ...                                                   ...          ...
# 150278  {'GoodForKids': 'True', 'RestaurantsPriceRange...  Active Life
# 150285  {'GoodForKids': 'True', 'BusinessParking': '{'...  Active Life
# 150303  {'BusinessAcceptsCreditCards': 'True', 'ByAppo...  Active Life
# 150334  {'ByAppointmentOnly': 'True', 'GoodForKids': '...  Active Life
# 150338  {'BusinessParking': '{'garage': False, 'street...  Active Life
#
#                                                     hours
# 30      {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:0'...
# 38      {'Monday': '10:0-15:0', 'Tuesday': '9:30-14:0'...
# 50      {'Monday': '5:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 100     {'Monday': '9:0-19:0', 'Tuesday': '9:0-15:30',...
# 109     {'Monday': '9:0-17:0', 'Tuesday': '9:0-17:0', ...
# ...                                                   ...
# 150278  {'Monday': '8:0-22:0', 'Tuesday': '8:0-22:0', ...
# 150285  {'Monday': '8:30-17:0', 'Tuesday': '8:30-17:0'...
# 150303  {'Monday': '10:0-22:0', 'Tuesday': '10:0-22:0'...
# 150334  {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 150338  {'Monday': '10:0-20:0', 'Tuesday': '10:0-20:30...
#
# [5842 rows x 14 columns]

# %% [markdown]
# ## Reading the data from Reviews dataset

# %%
#reading the data from yelp_academic_dataset_review
yelp_academic_dataset_review_json_path = '/Users/swapnakotha/Desktop/CMPE-257/yelp_dataset/yelp_academic_dataset_review.json'

# %%
#Date set which contain is very large(it contaings around 6 million reviews)
#Instead of reading it at once,read it in smaller part for
size = 1000000
review = pd.read_json(yelp_academic_dataset_review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int},
                      chunksize=size)

chunk_list = []

for chunk_review in review:
    chunk_review = chunk_review.drop(['review_id','useful','funny','cool'], axis=1)
    chunk_review = chunk_review.rename(columns={'stars': 'review_stars'})
    #Merge reviews which corresponds to the business that are categorized as 'Active_life'
    chunk_merged = pd.merge(active_life, chunk_review, on='business_id', how='inner')
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    chunk_list.append(chunk_merged)
active_life_review = pd.concat(chunk_list, ignore_index=True, join='outer', axis=0)
# Out:
# 26386 out of 1,000,000 related reviews
# 27572 out of 1,000,000 related reviews
# 25482 out of 1,000,000 related reviews
# 22872 out of 1,000,000 related reviews
# 23464 out of 1,000,000 related reviews
# 26750 out of 1,000,000 related reviews
# 23804 out of 1,000,000 related reviews

# %%
#Converting into CSV file
active_life_review.to_csv("active_life_reviews.csv",index=False)

# %%
#Taking the business which are classified as 'Restaurants' and creating a smaller subset
restaurants = df_categories_clean[df_categories_clean['categories'].str.contains("Restaurants")]

# %%
restaurants
# Out:
#                    business_id                           name  \
# 3       MTSW4McQd7CbVtyjqoe9mw             St Honore Pastries
# 5       CF33F8-E6oudUQ46HnavjQ                 Sonic Drive-In
# 9       bBDDEgkFA1Otx9Lfe7BZUQ                 Sonic Drive-In
# 11      eEOYSgkmpB90uNA7lDOMRA          Vietnamese Food Truck
# 12      il_Ro8jwPlHresjw9EGmBg                        Denny's
# ...                        ...                            ...
# 150325  l9eLGG9ZKpLJzboZq-9LRQ                           Wawa
# 150327  cM6V90ExQD6KMSU3rRB5ZA              Dutch Bros Coffee
# 150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
# 150339  2O2K6SXPWv56amqxCECd4w                   The Plum Pit
# 150340  hn9Toz3s-Ei3uZPt7esExA          West Side Kebab House
#
#                       address             city state postal_code   latitude  \
# 3                 935 Race St     Philadelphia    PA       19107  39.955505
# 5               615 S Main St     Ashland City    TN       37015  36.269593
# 9         2312 Dickerson Pike        Nashville    TN       37207  36.208102
# 11                                   Tampa Bay    FL       33602  27.955269
# 12               8901 US 31 S     Indianapolis    IN       46227  39.637133
# ...                       ...              ...   ...         ...        ...
# 150325        19 N Bishop Ave  Clifton Heights    PA       19018  39.925656
# 150327    1181 N Milwaukee St            Boise    ID       83704  43.615401
# 150336          1108 S 9th St     Philadelphia    PA       19147  39.935982
# 150339        4405 Pennell Rd            Aston    DE       19014  39.856185
# 150340  2470 Guardian Road NW         Edmonton    AB     T5T 1K8  53.509649
#
#          longitude  stars  review_count  is_open  \
# 3       -75.155564    4.0            80        1
# 5       -87.058943    2.0             6        1
# 9       -86.768170    1.5            10        1
# 11      -82.456320    4.0            10        1
# 12      -86.127217    2.5            28        1
# ...            ...    ...           ...      ...
# 150325  -75.310344    3.0            11        1
# 150327 -116.284689    4.0            33        1
# 150336  -75.158665    4.5            35        1
# 150339  -75.427725    4.5            14        1
# 150340 -113.675999    4.5            18        0
#
#                                                attributes   categories  \
# 3       {'RestaurantsDelivery': 'False', 'OutdoorSeati...  Restaurants
# 5       {'BusinessParking': 'None', 'BusinessAcceptsCr...  Restaurants
# 9       {'RestaurantsAttire': ''casual'', 'Restaurants...  Restaurants
# 11      {'Alcohol': ''none'', 'OutdoorSeating': 'None'...  Restaurants
# 12      {'RestaurantsReservations': 'False', 'Restaura...  Restaurants
# ...                                                   ...          ...
# 150325  {'BikeParking': 'True', 'BusinessAcceptsCredit...  Restaurants
# 150327  {'WiFi': ''free'', 'RestaurantsGoodForGroups':...  Restaurants
# 150336  {'WheelchairAccessible': 'False', 'Restaurants...  Restaurants
# 150339  {'RestaurantsDelivery': 'False', 'BusinessAcce...  Restaurants
# 150340  {'Ambience': '{'touristy': False, 'hipster': F...  Restaurants
#
#                                                     hours
# 3       {'Monday': '7:0-20:0', 'Tuesday': '7:0-20:0', ...
# 5       {'Monday': '0:0-0:0', 'Tuesday': '6:0-22:0', '...
# 9       {'Monday': '0:0-0:0', 'Tuesday': '6:0-21:0', '...
# 11      {'Monday': '11:0-14:0', 'Tuesday': '11:0-14:0'...
# 12      {'Monday': '6:0-22:0', 'Tuesday': '6:0-22:0', ...
# ...                                                   ...
# 150325  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150327  {'Monday': '0:0-0:0', 'Tuesday': '0:0-17:0', '...
# 150336  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
# 150339  {'Monday': '0:0-0:0', 'Tuesday': '0:0-0:0', 'W...
# 150340  {'Monday': '11:0-22:0', 'Tuesday': '11:0-22:0'...
#
# [44736 rows x 14 columns]

# %%
#Date set which contain is very large(it contaings around 6 million reviews)
#Instead of reading it at once,read it in smaller part for
size = 1000000
review = pd.read_json(yelp_academic_dataset_review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int},
                      chunksize=size)

# %%
restaurant_chunks = []
for chunk_review in review:
    chunk_review = chunk_review.drop(['review_id','useful','funny','cool'], axis=1)
    chunk_review = chunk_review.rename(columns={'stars': 'review_stars'})
    # Merge reviews which corresponds to the business that are categorized as 'Restaurants'
    chunk_merged = pd.merge(restaurants, chunk_review, on='business_id', how='inner')
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    restaurant_chunks.append(chunk_merged)
restaurant = pd.concat(restaurant_chunks, ignore_index=True, join='outer', axis=0)
# Out:
# 666750 out of 1,000,000 related reviews

# %%
restaurant

# %%
#converting it into 
restaurant.to_csv("restaurants_reviews.csv",index=False)

# %%
#Taking the business which are classified as 'medical' and creating a smaller subset
medical = df_categories_clean[df_categories_clean['categories'].str.contains("Health & Medical")]
medical

# %%
#Date set which contain is very large(it contaings around 6 million reviews)
#Instead of reading it at once,read it in smaller part for
size = 1000000
review = pd.read_json(yelp_academic_dataset_review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int},
                      chunksize=size)

# %%
medical_chunks = []
for chunk_review in review:
    chunk_review = chunk_review.drop(['review_id','useful','funny','cool'], axis=1)
    chunk_review = chunk_review.rename(columns={'stars': 'review_stars'})
    #Merge reviews which corresponds to the business that are categorized as 'medical'
    chunk_merged = pd.merge(medical, chunk_review, on='business_id', how='inner')
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    medical_chunks.append(chunk_merged)
medical_reviews = pd.concat(medical_chunks, ignore_index=True, join='outer', axis=0)

# %%
#converting into CSV file
medical_reviews.to_csv("medical_reviews.csv",index=False)

# %%
#Taking the business which are classified as 'Home Services' and creating a smaller subset
home_services = df_categories_clean[df_categories_clean['categories'].str.contains("Home Services")]
home_services

# %%
#Date set which contain is very large(it contaings around 6 million reviews)
#Instead of reading it at once,read it in smaller part for
size = 1000000
review = pd.read_json(yelp_academic_dataset_review_json_path, lines=True,
                      dtype={'review_id':str,'user_id':str,
                             'business_id':str,'stars':int,
                             'date':str,'text':str,'useful':int,
                             'funny':int,'cool':int},
                      chunksize=size)

# %%
homeservices_chunks = []
for chunk_review in review:
    chunk_review = chunk_review.drop(['review_id','useful','funny','cool'], axis=1)
    chunk_review = chunk_review.rename(columns={'stars': 'review_stars'})
    #Merge reviews which corresponds to the business that are categorized as 'Home_services'
    chunk_merged = pd.merge(home_services, chunk_review, on='business_id', how='inner')
    print(f"{chunk_merged.shape[0]} out of {size:,} related reviews")
    homeservices_chunks.append(chunk_merged)
homeservices_reviews = pd.concat(homeservices_chunks, ignore_index=True, join='outer', axis=0)

# %%
#converting into CSV file
homeservices_reviews.to_csv("homeservices_reviews.csv")

# %%
homeservices_reviews

# %%
active_life

# %%
active_life_review=pd.read_csv("active_life_reviews.csv")

# %%
active_life_review

# %% [markdown]
# ## Data visualization

# %%
#visual representation of distribution of review count for the business categorized as 'Active life' across the US states
fig1 = px.scatter_geo(active_life_review, locations='state', size='review_count', locationmode='USA-states', scope='usa', color='state', height=500,width=700, hover_name='state', labels={'state':'State', 'count':"Number of Complaints"})

# %%
fig1.show()

# %%
#reading the data of business categorized as restaurents 
restaurant=pd.read_csv("restaurants_reviews.csv")

# %%
restaurant['date']=pd.to_datetime(restaurant['date'])
restaurant_testing=restaurant

# %%
restaurant_testing=restaurant_testing.set_index('date')

# %%
#plot to show variation of review count across the years(from 2006 to 2022)
plt.plot(restaurant_testing['text'].resample('M').count())
plt.xlabel('Year')
plt.ylabel('Number of reviews')
plt.title('Restaurant --- Number of reviews per month')
plt.show()

# %%
#calculating the review distribution based on rating 
restaurant_testing_Stars = restaurant_testing['stars'].value_counts()
review_stars_percent = restaurant_testing_Stars.apply(lambda i : i / len(restaurant_testing) * 100)
review_stars_percent

# %%
#plot for review distribution
ax = review_stars_percent.sort_index(ascending=False).plot(kind='bar')
for patch in ax.patches:
    x = patch.get_bbox().get_points()[:, 0]
    y = patch.get_bbox().get_points()[1, 1]
    ax.annotate('{:.1f}%'.format(y), (x.mean(), y), ha='center', va='bottom')
plt.ylabel('Percentage of reviews')
plt.xlabel('Stars');

# %%
pysqldf = lambda q: sqldf(q, globals())

# %%
q = """SELECT state, count(*) as count
       FROM restaurant_testing
       group by state
       ;"""

# %%
missing = pysqldf(q)
missing

# %%
bus = pd.read_csv("business_updated.csv")
bus.head()

df_categories = bus.assign(categories = bus.categories.str.split(', ')).explode('categories')
df_categories.head()

print('Total number of categories:', len(df_categories.categories.value_counts()))
print('Top 20 categories:')
abc = df_categories.categories.value_counts()[:20]
abc.shape


from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

q = """SELECT categories, count(*) as count
       FROM df_categories
       group by categories
       ;"""

missing = pysqldf(q)
missing

# %%
restaurant_top = missing.sort_values('count')
Top20Cat = abc[-20:]

# %%
Top20Cat

# %%
fig = px.bar(Top20Cat)
fig.show()

# %%
from pandasql import sqldf
pysqldf = lambda q: sqldf(q, globals())

q = """SELECT state, count(*) as count
       FROM df_categories
       group by state
       ;"""

missing = pysqldf(q)
missing

# %%
restaurant_top_states = missing.sort_values('count')
Top10State = restaurant_top_states[-10:]

# %%
fig = px.bar(Top10State, x = 'state', y = 'count')
fig.show()

# %%
rest = pd.read_csv("restaurants_reviews.csv")
rest.head()

# %%
pysqldf = lambda q: sqldf(q, globals())

q = """SELECT name, count(*) as count
       FROM rest
       group by name
       ;"""

wordcloud1 = pysqldf(q)
wordcloud1

# %%
abc = wordcloud1.sort_values('count')
abc[-20:]

df = abc[-50:]
abc = ''.join(df['name'])

# %%
from wordcloud import WordCloud, STOPWORDS
import matplotlib.pyplot as plt

wordcloud = WordCloud(width = 800, height = 800,
                background_color ='white',
                stopwords = STOPWORDS,
                min_font_size = 10).generate(abc)

plt.figure(figsize = (8, 8), facecolor = None)
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0)
 
plt.show()

# %%
pysqldf = lambda q: sqldf(q, globals())

q = """SELECT name, count(*) as count
       FROM rest
       group by name
       ;"""

state_plot = pysqldf(q)
